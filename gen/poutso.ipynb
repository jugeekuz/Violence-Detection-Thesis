# %%
from utils import _load_samples_from_CSV

# %%
path1 = '../datasets/RWF-2000 Flows/data_files/train/Fight'
path2 = '../datasets/RWF-2000 Flows/data_files/train/NonFight'
samples1 = _load_samples_from_CSV(path1,10,4)
samples2 = _load_samples_from_CSV(path2,10,4)

# %%
x,y = samples1
x2,y2 = samples2

# %%
np.array(x).shape
# Out:
# (14400, 10)

# %%
features = []
features += x
features += x2
np.array(features).shape
# Out:
# (28800, 10)

# %%
classes_list = []
classes_list.append(y)
classes_list.append(y2)

# %%
c = np.array(classes_list)

# %%
c.shape
# Out:
# (2, 14400)

# %%
from frame_generator import FrameGenerator
import os

# %%
train_datagen = FrameGenerator(rescale = 1/255.,

# %%
path = os.path.normpath('datasets/RWF-2000 Flows/data_files/train')
train_gen = train_datagen.flow_from_CSV(path,temporal_length=10,temporal_stride=4)
# Out:
# Found 28800 sequences of 14400 images in total across 2 classes

# %%
(X,y) = next(train_gen)

# %%
from PIL import Image
import numpy as np
# data is your array

img = Image.fromarray(X[0,0,...], 'RGB')
#img.save('my.png')
img.show()

# %%
# Display the normalized image
import cv2
cv2.imshow('Normalized Image', X[0,0,...])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

plt.imshow(X[0,0,...],cmap='turbo')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
choice = np.random.choice([True,False])

# %%
choice
# Out:
# True
